# %%
alien_0 = {
    'color':'green',
    'points':5
}
print(alien_0['color'])
print(alien_0['points'])
# Out:
# green
# 5

# %%
new_points = alien_0['points']

# %%
print(new_points)
# Out:
# 5

# %%
print(f"You just earned {new_points} points!")
# Out:
# You just earned 5 points!

# %%
alien_0['x_position'] = 0
alien_0['y_position']= 25

print(alien_0)
# Out:
# {'color': 'green', 'points': 5, 'x_position': 0, 'y_position': 25}

# %%
alien_0['color'] = 'red'
alien_0['points'] = 50

print(alien_0)
# Out:
# {'color': 'red', 'points': 50, 'x_position': 0, 'y_position': 25}

# %%
alien = {}

# %%
alien['color'] = "Green"
alien['age'] = 69
alien['points']= 699

# %%
print(alien)
# Out:
# {'color': 'Green', 'age': 69, 'points': 699}

# %%
print(f"The alien color is {alien['color']}")
# Out:
# The alien color is Green

# %%
alien['color']= 'red'
print(f"Now the alien color is {alien['color']}")
# Out:
# Now the alien color is red

# %%
alien['speed'] = 'slow'

# %%
if alien['speed'] == 'slow':
    x_increment = 1
elif alien['speed'] == 'medium':
    x_increment = 2
else:
# This must be a fast alien.
    x_increment = 3

# %%
print(x_increment)
# Out:
# 1

# %%
alien["x_position"] = 68

# %%
alien['x_position'] = alien['x_position'] + x_increment

# %%
print(alien['x_position'])
# Out:
# 69

# %% [markdown]
# # Removing key value pair

# %%
del alien['color']

# %%
print(alien)
# Out:
# {'age': 69, 'points': 699, 'speed': 'slow', 'x_position': 69}

# %%
favorite_languages = {
'jen': 'python',
'sarah': 'c',
'edward': 'rust',
'phil': 'python',
}

# %%
print(favorite_languages['edward'])
# Out:
# rust

# %%
language = favorite_languages['sarah'].title()

# %%
print(language)
# Out:
# C

# %%
print(favorite_languages['fahad']) # will throw an error if key is not present
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 print(favorite_languages['fahad']) # will throw an error if key is not present
#
# KeyError: 'fahad'

# %%
favorite_languages.get("fahad","python")
# Out:
# 'python'

# %% [markdown]
# ## Looping

# %%
user_0 = {
'username': 'efermi',
'first': 'enrico',
'last': 'fermi',
}

# %%
for key,value in user_0.items():
    print(f"{key} - {value}")
# Out:
# username - efermi
# first - enrico
# last - fermi

# %%
for key in user_0.keys():
    print(f"{key} - {user_0[key]}")
# Out:
# username - efermi
# first - enrico
# last - fermi

# %%
# Make an empty list for storing aliens.
aliens = []

# Make 30 green aliens.
for alien_number in range(30):
    new_alien = {'color': 'green', 'points': 5, 'speed': 'slow'}
    aliens.append(new_alien)
for alien in aliens[:5]:
    print(alien)
    
print("...")
# Show how many aliens have been created.
print(f"Total number of aliens: {len(aliens)}")
# Out:
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# ...
# Total number of aliens: 30

# %%
# Store information about a pizza being ordered.
pizza = {
    'crust': 'thick',
    'toppings': ['mushrooms', 'extra cheese'],
}
# Summarize the order.
print(f"You ordered a {pizza['crust']}-crust pizza "
"with the following toppings:")

for topping in pizza['toppings']:
    print(f"\t{topping}")
# Out:
# You ordered a thick-crust pizza with the following toppings:
# 	mushrooms
# 	extra cheese

# %%
favorite_languages = {
'jen': ['python', 'rust'],
'sarah': ['c'],
'edward': ['rust', 'go'],
'phil': ['python', 'haskell'],
}
for name, languages in favorite_languages.items():
    print(f"\n{name.title()}'s favorite languages are:")
    for language in languages:
        print(f"\t{language.title()}")
# Out:
# Jen's favorite languages are:
# 	Python
# 	Rust
#
# Sarah's favorite languages are:
# 	C
#
# Edward's favorite languages are:
# 	Rust
# 	Go
#
# Phil's favorite languages are:
# 	Python
# 	Haskell

# %%
users = {
'aeinstein': {
'first': 'albert',
'last': 'einstein',
'location': 'princeton',
},
'mcurie': {
'first': 'marie',
'last': 'curie',
'location': 'paris',
},
}
for username, user_info in users.items():
    print(f"\nUsername: {username}")
    full_name = f"{user_info['first']} {user_info['last']}"
    location = user_info['location']
    print(f"\tFull name: {full_name.title()}")
    print(f"\tLocation: {location.title()}")
# Out:
# Username: aeinstein
# 	Full name: Albert Einstein
# 	Location: Princeton
#
# Username: mcurie
# 	Full name: Marie Curie
# 	Location: Paris
