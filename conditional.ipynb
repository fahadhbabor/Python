# %%
cars = ["audi",'bmw','toyota','subaru']

for car in cars:
    if car == 'bmw':
        print(car.upper())
    else:
        print(car.title())
# Out:
# Audi
# BMW
# Toyota
# Subaru

# %%
car = 'bmw'
car == 'bmw'
# Out:
# True

# %%
car = 'audi'
car == 'bmw'
# Out:
# False

# %%
car = 'Audi'
car.casefold() == 'audi'
# Out:
# True

# %%
age = 18

if age >= 18:
    print("You are eligible for vote")
elif age >= 16:
    print("You can vote partially")
else:
    print("You are not ready yet")
# Out:
# You are eligible for vote

# %%
age = 16
gender = 'male'

if age >= 18:
    print("You are eligible for vote")
elif age >= 16 and gender == 'male' :
    print("You can vote partially")
else:
    print("You are not ready yet")
# Out:
# You can vote partially

# %%
banned_users = ['fahad','hossain','babor']
user ='marie'

if user not in banned_users:
    print(f"{user.title()}, welcome to investor center.")
# Out:
# Marie, welcome to investor center.

# %%
age = 45

if age<4:
    price = 0
elif age < 10:
    price = 20
elif age < 40:
    price = 40
elif age >= 65:
    price=20

print(price)
# Out:
# 20

# %%
available_toppings = ['mushrooms','olives','green peppers','pepperoni','pineapple','extra cheese']
requested_toppings = ['mushrooms','french fries','extra cheese']

for requested_topping in requested_toppings:
    if requested_topping in available_toppings:
        print("Adding " + requested_topping)
    else:
        print("Sorry we dont have "+ requested_topping)

print("\n Finished making your pizza. Ready to serve")
# Out:
# Adding mushrooms
# Sorry we dont have french fries
# Adding extra cheese
#
#  Finished making your pizza. Ready to serve
