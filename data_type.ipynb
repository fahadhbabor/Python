# %%
x = "Fahad Hossain Babor" # str
print(x)
# Out:
# Fahad Hossain Babor

# %%
x = 20 #int
print(x)
# Out:
# 20

# %%
x = 69.9 # float
type(x)
# Out:
# float

# %%
x = 1j 
type(x)
# Out:
# complex

# %%
x = 1 + 2j
type(x)
# Out:
# complex

# %%
x = ["apple", "banana", "cherry"]
type(x)
# Out:
# list

# %%
x = ("apple", "banana", "cherry")
type(x)
# Out:
# tuple

# %%
x = range(6)
print(x)
type(x)
# Out:
# range(0, 6)
# range

# %%
x = {"name" : "John", "age" : 36}
print(x)
type(x)
# Out:
# {'name': 'John', 'age': 36}
# dict

# %%
x = {"apple", "banana", "cherry"}
print(type(x))
x.add("mango")
print(x)
# Out:
# <class 'set'>
# {'apple', 'cherry', 'banana', 'mango'}

# %%
x = frozenset({"apple", "banana", "cherry"})
print(type(x))
# x.add("mango") # cant add
# print(x)
# Out:
# <class 'frozenset'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 3
#       1 x = frozenset({"apple", "banana", "cherry"})
#       2 print(type(x))
# ----> 3 x.add("mango")
#       4 print(x)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
#bool
x = True

# %%
#byte array
x = b"Hello"
print(x)
# Out:
# b'Hello'
