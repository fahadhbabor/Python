# %% [markdown]
# # Hello world

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("I am Fahad Hossain Babor")
# Out:
# I am Fahad Hossain Babor

# %%
print("I am learning python")
# Out:
# I am learning python

# %%
print("Python is awesome")
# Out:
# Python is awesome
